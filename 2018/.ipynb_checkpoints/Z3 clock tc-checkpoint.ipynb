# %%
import numpy as np
import matplotlib.pyplot as plt
from simulation import *

# %%
spec_names=('gap', 'shifted_gap', 'log10_gap', 'log10_shifted_gap', 'ratio')

# %%
dim_loc=3
L=5
n_dis=100
simdict={'dim_loc': dim_loc, 'L': L, 'n_dis': n_dis}
phi=np.pi/6
time_set= np.power(2, np.arange(40))
idata={'JZZ': 1.0, 'hZ': 0.3, 'hX': 0.1, 'alphas': np.array([np.exp(1j*phi), np.exp(-1j*phi)]),\
       'betas': np.ones(dim_loc-1), 'lambdas': np.ones(dim_loc-1), 'phi': phi}
filename='clock3_'+str(L)+'.txt'

# %%
clockH, clockK, clockZ = clock(dim_loc, L)
Z_mean, Z_var, spectral_data, spectral_data_var = simulation(dim_loc, L, n_dis, idata, clockH, clockK, clockZ, time_set)

with open(filename, 'wb') as f:
        for key, value in simdict.items():
            f.write(('\n# '+key+' '+str(value)).encode('utf-8'))
        for key, value in idata.items():
            f.write(('\n# '+key+' '+str(value)).encode('utf-8'))
        for i in range(5):
            f.write(('\n# '+spec_names[i]+' '+str(spectral_data[i])+' '+str(spectral_data_var[i])).encode('utf-8'))
        f.write('\n# time\tRe(Z)\Im(Z)\tVar(Re(Z))\tVar(Im(Z))\n'.encode('utf-8'))
        np.savetxt(f, np.stack((time_set, np.real(Z_mean), np.imag(Z_mean), np.real(Z_var), np.imag(Z_var)), axis=-1))
# Out:
# size 5 	disorder realization 0 	time elapsed 0.3951399326324463
# size 5 	disorder realization 1 	time elapsed 0.44855213165283203
# size 5 	disorder realization 2 	time elapsed 0.6248669624328613
# size 5 	disorder realization 3 	time elapsed 0.39488697052001953
# size 5 	disorder realization 4 	time elapsed 0.6608462333679199
# size 5 	disorder realization 5 	time elapsed 0.8465783596038818
# size 5 	disorder realization 6 	time elapsed 0.6173365116119385
# size 5 	disorder realization 7 	time elapsed 0.6353888511657715
# size 5 	disorder realization 8 	time elapsed 0.6212103366851807
# size 5 	disorder realization 9 	time elapsed 0.5844461917877197
# size 5 	disorder realization 10 	time elapsed 0.5659451484680176
# size 5 	disorder realization 11 	time elapsed 0.40970563888549805
# size 5 	disorder realization 12 	time elapsed 0.43209242820739746
# size 5 	disorder realization 13 	time elapsed 0.4401099681854248
# size 5 	disorder realization 14 	time elapsed 0.42649149894714355
# size 5 	disorder realization 15 	time elapsed 0.43413472175598145
# size 5 	disorder realization 16 	time elapsed 0.45429277420043945
# size 5 	disorder realization 17 	time elapsed 0.43016839027404785
# size 5 	disorder realization 18 	time elapsed 0.4498908519744873
# size 5 	disorder realization 19 	time elapsed 0.40935802459716797
# size 5 	disorder realization 20 	time elapsed 0.41262197494506836
# size 5 	disorder realization 21 	time elapsed 0.39975690841674805
# size 5 	disorder realization 22 	time elapsed 0.4018397331237793
# size 5 	disorder realization 23 	time elapsed 0.40967869758605957
# size 5 	disorder realization 24 	time elapsed 0.41923952102661133
# size 5 	disorder realization 25 	time elapsed 0.3892242908477783
# size 5 	disorder realization 26 	time elapsed 0.41024065017700195
# size 5 	disorder realization 27 	time elapsed 0.40952014923095703
# size 5 	disorder realization 28 	time elapsed 0.39770078659057617
# size 5 	disorder realization 29 	time elapsed 0.4293098449707031
# size 5 	disorder realization 30 	time elapsed 0.5097641944885254
# size 5 	disorder realization 31 	time elapsed 0.4125998020172119
# size 5 	disorder realization 32 	time elapsed 0.4252665042877197
# size 5 	disorder realization 33 	time elapsed 0.4110450744628906
# size 5 	disorder realization 34 	time elapsed 0.6686298847198486
# size 5 	disorder realization 35 	time elapsed 0.7573037147521973
# size 5 	disorder realization 36 	time elapsed 0.7249791622161865
# size 5 	disorder realization 37 	time elapsed 0.7572715282440186
# size 5 	disorder realization 38 	time elapsed 0.601804256439209
# size 5 	disorder realization 39 	time elapsed 0.7331500053405762
# size 5 	disorder realization 40 	time elapsed 0.7484593391418457
# size 5 	disorder realization 41 	time elapsed 0.5964827537536621
# size 5 	disorder realization 42 	time elapsed 0.8165016174316406
# size 5 	disorder realization 43 	time elapsed 0.4064595699310303
# size 5 	disorder realization 44 	time elapsed 0.40834736824035645
# size 5 	disorder realization 45 	time elapsed 0.44612598419189453
# size 5 	disorder realization 46 	time elapsed 0.48714733123779297
# size 5 	disorder realization 47 	time elapsed 0.4318559169769287
# size 5 	disorder realization 48 	time elapsed 0.5295639038085938
# size 5 	disorder realization 49 	time elapsed 0.43863630294799805
# size 5 	disorder realization 50 	time elapsed 0.41631007194519043
# size 5 	disorder realization 51 	time elapsed 0.5593345165252686
# size 5 	disorder realization 52 	time elapsed 0.6351876258850098
# size 5 	disorder realization 53 	time elapsed 0.6505348682403564
# size 5 	disorder realization 54 	time elapsed 0.6088197231292725
# size 5 	disorder realization 55 	time elapsed 0.9080784320831299
# size 5 	disorder realization 56 	time elapsed 0.48498988151550293
# size 5 	disorder realization 57 	time elapsed 0.530864953994751
# size 5 	disorder realization 58 	time elapsed 0.4143555164337158
# size 5 	disorder realization 59 	time elapsed 0.5246727466583252
# size 5 	disorder realization 60 	time elapsed 0.4748070240020752
# size 5 	disorder realization 61 	time elapsed 0.6099991798400879
# size 5 	disorder realization 62 	time elapsed 0.4944305419921875
# size 5 	disorder realization 63 	time elapsed 0.6350018978118896
# size 5 	disorder realization 64 	time elapsed 0.48367786407470703
# size 5 	disorder realization 65 	time elapsed 0.38715529441833496
# size 5 	disorder realization 66 	time elapsed 0.5355114936828613
# size 5 	disorder realization 67 	time elapsed 0.6135897636413574
# size 5 	disorder realization 68 	time elapsed 0.6085622310638428
# size 5 	disorder realization 69 	time elapsed 0.6945803165435791
# size 5 	disorder realization 70 	time elapsed 0.576242208480835
# size 5 	disorder realization 71 	time elapsed 0.5366818904876709
# size 5 	disorder realization 72 	time elapsed 0.6493475437164307
# size 5 	disorder realization 73 	time elapsed 0.572810173034668
# size 5 	disorder realization 74 	time elapsed 0.5601210594177246
# size 5 	disorder realization 75 	time elapsed 0.6188127994537354
# size 5 	disorder realization 76 	time elapsed 0.4438185691833496
# size 5 	disorder realization 77 	time elapsed 0.3777594566345215
# size 5 	disorder realization 78 	time elapsed 0.4195213317871094
# size 5 	disorder realization 79 	time elapsed 0.41373610496520996
# size 5 	disorder realization 80 	time elapsed 0.4080953598022461
# size 5 	disorder realization 81 	time elapsed 0.4072093963623047
# size 5 	disorder realization 82 	time elapsed 0.42961668968200684
# size 5 	disorder realization 83 	time elapsed 0.5325367450714111
# size 5 	disorder realization 84 	time elapsed 0.4173898696899414
# size 5 	disorder realization 85 	time elapsed 0.4143962860107422
# size 5 	disorder realization 86 	time elapsed 0.4005258083343506
# size 5 	disorder realization 87 	time elapsed 0.38755178451538086
# size 5 	disorder realization 88 	time elapsed 0.4454820156097412
# size 5 	disorder realization 89 	time elapsed 0.4481239318847656
# size 5 	disorder realization 90 	time elapsed 0.49727678298950195
# size 5 	disorder realization 91 	time elapsed 0.4619925022125244
# size 5 	disorder realization 92 	time elapsed 0.6371731758117676
# size 5 	disorder realization 93 	time elapsed 0.41738367080688477
# size 5 	disorder realization 94 	time elapsed 0.40411376953125
# size 5 	disorder realization 95 	time elapsed 0.41123247146606445
# size 5 	disorder realization 96 	time elapsed 0.4146707057952881
# size 5 	disorder realization 97 	time elapsed 0.44577813148498535
# size 5 	disorder realization 98 	time elapsed 0.4331798553466797
# size 5 	disorder realization 99 	time elapsed 0.6841013431549072

# %%
import re

lenarr=len(time_set)

dt = np.dtype([('JZZ', np.float64), ('hZ', np.float64), ('hX', np.float64), 
               ('FILENAME', np.unicode_, 32), ('phi', np.float64), ('dim_loc', np.int32),
               ('n_dis', np.int32), ('L', np.int32), ('time_set', np.float64, (lenarr,)),
               ('ReZ', np.float64, (lenarr,)), ('ImZ', np.float64, (lenarr,)), ('ReVarZ', np.float64, (lenarr,)),
               ('ImVarZ', np.float64, (lenarr,))])

def get_data(file):
    d = np.zeros([], dtype=dt)
    d['FILENAME']=file
    with open(file) as f:
        for line in f:
            try:
                m = re.match("# (\S+) ([-+]?\d+.\d+e[+-]?\d+)", line)
                d[m.group(1)]=float(m.group(2))
            except:
                try:
                    m = re.match("# (\S+) ([-+]?\d+.\d+)", line)
                    d[m.group(1)]=float(m.group(2))                  
                except:
                    try:
                        m = re.match("# (\S+) (\d+)", line)
                        d[m.group(1)]=int(m.group(2))                       
                    except: pass
    d['time_set'], d['ReZ'], d['ImZ'], d['ReVarZ'], d['ImVarZ']=np.genfromtxt(file, unpack=True, dtype=np.complex128)
    return d

# %%
dataset=np.empty(0, dtype=dt)
for L in range(2,6):
    d=get_data('clock3_%d.txt' %L)
    dataset=np.append(dataset, d)
# Out:
# /home/federica/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:28: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
f, ax = plt.subplots(1,1,figsize=(10,6))

for sim in dataset:
    ax.plot(np.log10(sim['time_set']), sim['ReZ'],label= r'$L=$%d' % L)

plt.show()

# %%
def get_data(file):
    d = np.zeros([], dtype=dt)
    d['FILENAME']=file
    with open(file) as f:
        for line in f:
            try:
                m = re.match("# (\S+) ([-+]?\d+.\d+e[+-]?\d+)", line)
                d[m.group(1)]=float(m.group(2))
            except:
                try:
                    m = re.match("# (\S+) ([-+]?\d+.\d+)", line)
                    d[m.group(1)]=float(m.group(2))                  
                except:
                    try:
                        m = re.match("# (\S+) (\d+)", line)
                        d[m.group(1)]=int(m.group(2))                       
                    except: pass
    d['time_set'], d['ReZ'], d['ImZ'], Varz=np.genfromtxt(file, unpack=True, dtype=np.complex128)
    return d

# %%
dataset=np.empty(0, dtype=dt)
for L in range(2,7):
    d=get_data('pertkick/Z_02_0%d.dat' %L)
    dataset=np.append(dataset, d)
# Out:
# /home/federica/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:18: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
f, ax = plt.subplots(1,1,figsize=(5,3))

for sim in dataset:
    ax.plot(np.log10(sim['time_set']), sim['ReZ'],label= r'$L=$%d' % sim['L'])

ax.set_xlabel(r'$\log_{10} (t/T)$')
ax.set_ylabel(r'$|Z(t)|$')
ax.legend()
plt.tight_layout()
#plt.show()
#plt.savefig('pertkick/pertkick2.eps')

# %%
f2, ax2 = plt.subplots(1,1,figsize=(7,4))
phivec=np.array([np.pi/24, np.pi/12, np.pi/8, np.pi/6, -np.pi/24, -np.pi/12, -np.pi/8, -np.pi/6])

phinum=2

linesym=[]

for L in range(2,6):
    epsilon, gaps, shifted_gaps, log10_gaps, log10_shifted_gaps, ratio,\
    var_gaps, var_shifted_gaps, var_log10_gaps, var_log10_shifted_gaps, var_ratio\
        = np.loadtxt('pertkick_spectrum/spectrum_07_0%d.dat' %L, unpack=True)
    ax2.plot(np.log10(epsilon), log10_shifted_gaps,label= r'$L=$%d' % L, color='C%d' %(L-2),marker='s', linestyle='')
    ax2.plot(np.log10(epsilon), log10_gaps, marker='o', color='C%d' %(L-2), linestyle='')
    linesym.append(plt.Line2D((0,1),(0,0), color='C%d' %(L-2)))


#Get artists and labels for legend and chose which ones to display
handles, labels = ax2.get_legend_handles_labels()
labels, linesym = zip(*sorted(zip(labels, linesym), key=lambda t: t[0]))

#Create custom artists
symo = plt.Line2D((0,1),(0,0), color='k', marker='o', linestyle='')
syms = plt.Line2D((0,1),(0,0), color='k', marker='s', linestyle='')

#Create legend from custom artist/label lists
#figleg, axleg=plt.subplots(nrows=1, figsize=(2,2.5))
#axleg.axis('off')
#legend=axleg.legend(list(linesym)+[symo, syms], list(labels)+['$\log_{10}\Delta_0$', '$\log_{10}\Delta$'], loc='upper center', shadow=False, numpoints=1)
legend=ax2.legend(list(linesym)+[symo, syms], list(labels)+['$\log_{10}\Delta_0$', '$\log_{10}\Delta$'], loc='lower right', shadow=False, numpoints=1)
    
ax2.set_xlabel(r'$\log_{10} \epsilon$')
plt.tight_layout()
